# %% [markdown]
# <a href="https://colab.research.google.com/github/uzzal-hossen-2024/FL-Learning/blob/main/FL_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ok")
# Out:
# ok
